# %% [markdown]
# # Hello World
#
# A starter notebook for the World Development Indicators project.

# %%
print("Hello, World!")

# %%
import numpy as np
import pandas as pd

sample = pd.DataFrame({
    "indicator": ["Population", "GDP", "Life expectancy"],
    "value": np.array([1, 2, 3]),
})

sample
